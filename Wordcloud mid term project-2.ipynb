# %%
#wordcloud
# %pip install wordcloud
# %pip install matplotlib
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/6a/cf/4b158a4847515c757398a6762e0c0473278dfe6cfb5dd018e09853b25dba/wordcloud-1.9.2-cp39-cp39-macosx_10_9_x86_64.whl.metadata
#   Downloading wordcloud-1.9.2-cp39-cp39-macosx_10_9_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy>=1.6.1 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (5.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.2-cp39-cp39-macosx_10_9_x86_64.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.1/161.1 kB 3.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (5.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/susanndinoshinge/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " Nomads, community, lifestyle, storytelling, giveaway, tips, join, travel memes, remote work, visa, traveling, work, companies, interviews"

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axis
plt.show()
